# %%
import pandas as pd

student_csv = pd.read_csv('student_data.csv')
# print(student_csv)

# print(student_csv.head(10))
# print(student_csv.shape)
# print(student_csv.info(10))

student_csv['Assignment_Completion_%'].describe()
student_csv['Communication_Skill_(10)'].value_counts()
student_csv.isnull().sum()

student_csv.groupby('Placed')[['Assignment_Completion_%', 'Communication_Skill_(10)', 'Content_Score_Avg']].mean().round(2)

student_csv[['Assignment_Completion_%', 'CTC_LPA']].corr()

student_csv.sort_values('Assignment_Completion_%', ascending=False).head(10)

student_csv.groupby('Course')['CTC_LPA'].mean()

student_csv[(student_csv['Content_Score_Avg'] > 80) & (student_csv['Communication_Skill_(10)'] > 8) & (student_csv['Placed'] == 'No')]
# Out:
#    Student_ID Student_Name     Course  Assignment_Completion_%  \
# 48     STU049  Arjun Kumar  Python DA                       53
#
#     Content_Score_Avg  Communication_Skill_(10) Batch_Start_Date Placed  \
# 48                 83                        10       2024-10-22     No
#
#     CTC_LPA
# 48      NaN
